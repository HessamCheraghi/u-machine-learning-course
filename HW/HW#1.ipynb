# %% [markdown]
# # Machine Learning HW#1
#
# ## Contributors
#   - Ahmad Ehteshami
#   - Amir Hossein Kazemi Sheikh Zadeh
#   - Hessam A. Cheraghi
# ## Submission Time
#   `November 5th 2024 (14 Aban 1403)`
# ## Answers
# ### Part #1

# %%
# my first python program
print("hello world!")
# Out:
# hello world!

# %%
# let's build a magical calculator
print('Welcome to the 🎩magical🎩 calculator')
print('Maybe you have a chance to learn 📟math📟 today?')
print('first gimme two numbers✌')
a = int(input("the first number: \t"))
b = int(input("the second number: \t"))
print("Wow! you actually put two numbers. Interesting...")
print("Here are the magic results🪄\n")
print(a, "+", b, "=", a + b)
print(a, "-", b, "=", a - b)
print(a, "×", b, "=", a * b)
print(a, "/", b, "=", a / b)
print("\nHope you learn something today🤪 bye!")
# Out:
# Welcome to the 🎩magical🎩 calculator
# Maybe you have a chance to learn 📟math📟 today?
# first gimme two numbers✌
# Wow! you actually put two numbers. Interesting...
# Here are the magic results🪄
#
# 20 + 5 = 25
# 20 - 5 = 15
# 20 × 5 = 100
# 20 / 5 = 4.0
#
# Hope you learn something today🤪 bye!

# %%
# time to get serious. let's make a chart!
import matplotlib.pyplot as plt

x = [1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1402,1403]
y = [1800,3800,3600,3550,3600,3425,4250,15067,15757,23963,27735,35470,58313,72000]

plt.style.use('dark_background')
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Price")
plt.title("USD-IRT")
plt.grid()

# %% [markdown]
# ### Part #2

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

data = pd.read_csv("HW#1StudentsPerformance.csv")

data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
x = data['math score']
y = data['writing score']

plt.style.use('dark_background')
plt.scatter(x, y)
plt.xlabel('math score')
plt.ylabel('writing score')
plt.title("Writing score based on Math score")
plt.show()

# %%
model = sm.OLS(y,sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          writing score   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     1807.
# Date:                Sun, 03 Nov 2024   Prob (F-statistic):          3.38e-226
# Time:                        18:36:38   Log-Likelihood:                -3622.7
# No. Observations:                1000   AIC:                             7249.
# Df Residuals:                     998   BIC:                             7259.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.8942      1.283     11.609      0.000      12.377      17.412
# math score     0.8044      0.019     42.511      0.000       0.767       0.841
# ==============================================================================
# Omnibus:                       39.851   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.007
# Skew:                          -0.108   Prob(JB):                     7.46e-05
# Kurtosis:                       2.360   Cond. No.                         303.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.style.use('dark_background')
plt.scatter(x, y)


x_coef = model.params['math score']
const = model.params['const']
y_hat = x_coef * x + const
fig = plt.plot(x,y_hat,  lw=3, c='hotpink')

plt.xlabel('math score')
plt.ylabel('writing score')
plt.title("Writing score based on Math score")

plt.show()
